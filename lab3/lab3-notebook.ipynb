# %% [markdown]
# ## Background
#
# - **Sampling rate (SF)**: (also called sampling frequency) is a measure of how often an analog signal is converted to a digital signal. In other words, it is the number of times per second that an analog signal is measured and recorded in a digital form.
# - **Sampling Period (SP)**: represents the time interval between two consecutive samples of a continuous signal. It is expressed in seconds and is given by the formula: SP = 1 / SF

# %% [markdown]
# ### 1. Fourier transform (1D)

# %% [markdown]
# #### 1.1) Construct the following signal characterized by a sampling frequency equal to SR=50 and constituted by the sum of cosine functions with frequencies equal to 5 and 9 respectively:
# ```python
#    s = 1 + np.cos(2 * np.pi * 5 * t) + 0.3 * np.cos(2 * np.pi * 9 * t)
# ```
# ![image](../images/image_03.png)

# %%
import matplotlib.pyplot as plt
import numpy as np

SR = 100
t = np.arange(0, 1, 1/SR)
s = 1 + np.cos(2 * np.pi * 5 * t) + 0.3 * np.cos(2 * np.pi * 9 * t)
# visualize the signal
plt.plot(t, s)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Signal')
plt.show()

# %% [markdown]
# #### 1.2) Compute the 1D Fourier transform using the function provided in the file `ressources.py`. Visualize the results and interpret them.

# %% [markdown]
# ### 2. Fourier transform (2D) on sinusoidal images

# %% [markdown]
# #### 2.1) Using the wave function defined in the file `wave.py`, create a sinusoidal image of size **128x128** with oscillations of frequency 0.1 along the vertical axis only. Visualize the obtained image.

# %% [markdown]
# #### 2.2) Using the function `fourier_all`, calculate the spectrum of Fourier of the image and visualize it. Interpret your results.

# %% [markdown]
# #### 2.3) Try to generate oscillations of frequency 0.1 along the horizontal axis. Visualize the image. Compute its Fourier spectrum, visualize it and interpret it.

# %% [markdown]
# ### 3. Fourier transform (2D) on synthetic images

# %% [markdown]
# *Let's do the same processing to the images located in the folder `Synthetic_images`. Visualize, analyze, and interpret your results.*

# %% [markdown]
# ### 4. Filtering based on Fourier transform (2D)

# %% [markdown]
# ![ff](../images/image_04.png)

# %% [markdown]
# #### 4.1) Having the `Lena.png` image, you are invited to implement a function that performs filtering similar to figure 1. The radius must be an entry of the function. The function should be able to plot the mask on the Fourier spectrum so you can visualize it. Try to visualize the masks and the results related to different adius of the mask.

# %% [markdown]
# #### 4.2) What type of filtering is that? How can you simply improve the filtering result?

# %% [markdown]
# #### 4.3) Can you implement the inverse of that filtering following the same idea?
